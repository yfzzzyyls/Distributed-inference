# %% [markdown]
# # MultiUser Speculative Decode

# %% [markdown]
# ## Client

# %%
from draft_client import ModelServiceClient

client = ModelServiceClient(
        model_name='/home/apc/llama/Qwen2.5-0.5B-Instruct', 
        server_address='localhost:2024', 
        quantize=True, 
        max_length=50, 
        generate_step=4
)
# client.compare_generate(prompt)
# Out:
# /home/apc/miniconda3/envs/default/lib/python3.12/site-packages/google/protobuf/runtime_version.py:112: UserWarning: Protobuf gencode version 5.27.2 is older than the runtime version 5.28.2 at protos/model_service.proto. Please avoid checked-in Protobuf gencode that can be obsolete.
#   warnings.warn(
# `low_cpu_mem_usage` was None, now set to True since model is quantized.

# %%
print(client.speculative_decode_thread("Hello"))
print(client.traditional_generate("Hello"))
# Out:
# ok
# server output: Hello,
# /home/apc/miniconda3/envs/default/lib/python3.12/site-packages/torch/utils/cpp_extension.py:1965: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# /home/apc/miniconda3/envs/default/lib/python3.12/site-packages/quanto/library/ops.py:66: UserWarning: An exception was raised while calling the optimized kernel for quanto::unpack: /home/apc/miniconda3/envs/default/bin/../lib/libstdc++.so.6: version `GLIBCXX_3.4.32' not found (required by /home/apc/.cache/torch_extensions/py312_cu121/quanto_cuda/quanto_cuda.so) Falling back to default implementation.
#   warnings.warn(message + " Falling back to default implementation.")
# Starting from v4.46, the `logits` model output will have the same type as the model (except at train time, where it will always be FP32)
# draft output:  everyone
# draft output: !
# ...

# %%
from datasets import load_dataset

dataset = load_dataset("xsum", split="test[:5]")  # 这里只用前10个样本进行演示

# 循环接受多次输入
for i, example in enumerate(dataset):
    prompt = example["document"][:200]
    print(f"第 {i + 1} 个样本：{prompt}")
    
    print(client.speculative_decode_thread(prompt))
    print(client.traditional_generate(prompt))
# Out:
# 第 1 个样本：Prison Link Cymru had 1,099 referrals in 2015-16 and said some ex-offenders were living rough for up to a year before finding suitable accommodation.
# Workers at the charity claim investment in housing
# /home/apc/miniconda3/envs/default/lib/python3.12/site-packages/torch/utils/cpp_extension.py:1965: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# /home/apc/miniconda3/envs/default/lib/python3.12/site-packages/quanto/library/ops.py:66: UserWarning: An exception was raised while calling the optimized kernel for quanto::unpack: /home/apc/miniconda3/envs/default/bin/../lib/libstdc++.so.6: version `GLIBCXX_3.4.32' not found (required by /home/apc/.cache/torch_extensions/py312_cu121/quanto_cuda/quanto_cuda.so) Falling back to default implementation.
#   warnings.warn(message + " Falling back to default implementation.")
# ...
